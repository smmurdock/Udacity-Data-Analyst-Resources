# %% [markdown]
# # Merging Datasets
# Use pandas Merges to create a combined dataset from `clean_08.csv` and `clean_18.csv`. You should've created these data files in the previous section: *Fixing Data Types*.

# %%
# load datasets
import pandas as pd

df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %% [markdown]
# ### Create combined dataset

# %%
# rename 2008 columns
df_08.rename(columns=lambda x: x[:10] + "_2008", inplace=True)

# %%
# view to check names
df_08.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2   ACURA RL         3.5         6    Auto-S5        4WD  Gasoline
# 3   ACURA TL         3.2         6    Auto-S5        2WD  Gasoline
# 4   ACURA TL         3.5         6    Auto-S5        2WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008  cmb_mpg_2008  \
# 0            SUV              7.0           15.0          20.0          17.0
# 1            SUV              7.0           17.0          22.0          19.0
# 2    midsize car              7.0           16.0          24.0          19.0
# 3    midsize car              7.0           18.0          26.0          21.0
# 4    midsize car              7.0           17.0          26.0          20.0
#
#    greenhouse_2008 smartway_2008
# 0                4            no
# 1                5            no
# 2                5            no
# 3                6           yes
# 4                6           yes

# %%
# merge datasets
df_combined = pd.concat([df_08, df_18])

# %%
# view to check merge
df_combined.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA MDX         3.7       6.0    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3       4.0    Auto-S5        4WD  Gasoline
# 2   ACURA RL         3.5       6.0    Auto-S5        4WD  Gasoline
# 3   ACURA TL         3.2       6.0    Auto-S5        2WD  Gasoline
# 4   ACURA TL         3.5       6.0    Auto-S5        2WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008  ...  trans  \
# 0            SUV              7.0           15.0          20.0  ...    NaN
# 1            SUV              7.0           17.0          22.0  ...    NaN
# 2    midsize car              7.0           16.0          24.0  ...    NaN
# 3    midsize car              7.0           18.0          26.0  ...    NaN
# 4    midsize car              7.0           17.0          26.0  ...    NaN
#
#    drive fuel veh_class  air_pollution_score  city_mpg hwy_mpg cmb_mpg  \
# 0    NaN  NaN       NaN                  NaN       NaN     NaN     NaN
# 1    NaN  NaN       NaN                  NaN       NaN     NaN     NaN
# 2    NaN  NaN       NaN                  NaN       NaN     NaN     NaN
# 3    NaN  NaN       NaN                  NaN       NaN     NaN     NaN
# 4    NaN  NaN       NaN                  NaN       NaN     NaN     NaN
#
#   greenhouse_gas_score smartway
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# Save the combined dataset

# %%
df_combined.to_csv('combined_dataset.csv', index=False)
